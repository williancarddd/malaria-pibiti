# %%
import pandas as pd
import os
from pathlib import Path

# %%
NEURAL_NETWORKS = ['DenseNet201', 'MobileNetV2', 'InceptionV3', "ResNet50"]
COLUMNS = ["accuracy", "precision","sensitivity", "specificity", "f1_score", "auc", "npv", "mcc", "val_accuracy", "val_precision", "val_specificity", "val_f1_score", "val_auc", "val_npv", "val_mcc"]
SUBSETS = ['Dataset01_100', 'Dataset01_95.0', 'Dataset01_90.0', 'Dataset01_85.0', 'Dataset01_80.0', 'Dataset01_75.0', 
           'Dataset01_70.0', 'Dataset01_65.0', 'Dataset01_60.0', 'Dataset01_55.0', 'Dataset01_50.0', 'Dataset01_45.0',
           'Dataset01_40.0', 'Dataset01_35.0', 'Dataset01_30.0', 'Dataset01_25.0', 'Dataset01_20.0', 'Dataset01_15.0', 
           'Dataset01_10.0', 'Dataset01_5.0']

# %%
path_project = Path().absolute().parent.parent.parent
results_path = path_project / "6_resultados"

# %%
result_ultimate = {}
for network in NEURAL_NETWORKS:
    output_file = results_path / 'analitycs' / 'by_train' / '_pre_plot' / f'{network}_result_for_analytic.csv'
    for subset in SUBSETS:
        # Path to the CSVs for training
        csvs_path = results_path / subset / network / "metrics" / "csvs" / "_refined"
        if not os.path.exists(csvs_path):
            continue
        print(csvs_path)
       
        # Read and concatenate training CSV files
        if os.path.isfile(output_file):
            result_df = pd.read_csv(output_file)
        else:
            result_df = pd.DataFrame()

        df = pd.read_csv(csvs_path / os.listdir(csvs_path)[0])
        
        runtime = df["runtime"].mean()
        val_runtime = df["val_runtime"].mean()
        total_runtime = runtime + val_runtime
        result_data = {"subset": int(float(subset.split("_")[-1])), "model": network,
                        "runtime": runtime, "val_runtime": val_runtime, "total_runtime": total_runtime}
        for column in COLUMNS:
            first_quartile, third_quartile = df[column].quantile([
                0.25, 0.75
            ])

            iqr = third_quartile - first_quartile
            column_median = df[column].median()
            column_mean = df[column].mean()

            lower_whisker = 100 * (first_quartile - 1.5 * iqr)
            upper_whisker = 100 * (third_quartile + 1.5 * iqr)

            result_data[f"{column}_mean"] = 100 * column_mean
            result_data[f"{column}_median"] = 100 * column_median
            result_data[f"{column}_lower"] = 100 * first_quartile
            result_data[f"{column}_upper"] = 100 * third_quartile
            result_data[f"{column}_lower_whisker"] = lower_whisker
            result_data[f"{column}_upper_whisker"] = upper_whisker
        result_temp_df = pd.DataFrame([result_data])
        result_df = pd.concat(
            [result_df, result_temp_df], ignore_index=True)
        result_df = result_df.sort_values(by=["subset"])
        # result_df: pd.DataFrame = result_df.append(result_data, ignore_index = True)
        result_df.to_csv(output_file, index=None)
# Out:
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_100/DenseNet201/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_95.0/DenseNet201/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_90.0/DenseNet201/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_85.0/DenseNet201/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_80.0/DenseNet201/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_75.0/DenseNet201/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_70.0/DenseNet201/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_65.0/DenseNet201/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_60.0/DenseNet201/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_55.0/DenseNet201/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_50.0/DenseNet201/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_45.0/DenseNet201/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_40.0/DenseNet201/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_35.0/DenseNet201/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_30.0/DenseNet201/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_25.0/DenseNet201/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_20.0/DenseNet201/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_15.0/DenseNet201/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_10.0/DenseNet201/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_5.0/DenseNet201/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_100/MobileNetV2/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_95.0/MobileNetV2/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_90.0/MobileNetV2/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_85.0/MobileNetV2/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_80.0/MobileNetV2/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_75.0/MobileNetV2/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_70.0/MobileNetV2/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_65.0/MobileNetV2/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_60.0/MobileNetV2/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_55.0/MobileNetV2/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_50.0/MobileNetV2/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_45.0/MobileNetV2/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_40.0/MobileNetV2/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_35.0/MobileNetV2/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_30.0/MobileNetV2/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_25.0/MobileNetV2/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_20.0/MobileNetV2/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_15.0/MobileNetV2/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_10.0/MobileNetV2/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_5.0/MobileNetV2/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_100/InceptionV3/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_95.0/InceptionV3/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_90.0/InceptionV3/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_85.0/InceptionV3/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_80.0/InceptionV3/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_75.0/InceptionV3/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_70.0/InceptionV3/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_65.0/InceptionV3/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_60.0/InceptionV3/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_55.0/InceptionV3/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_50.0/InceptionV3/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_45.0/InceptionV3/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_40.0/InceptionV3/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_35.0/InceptionV3/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_30.0/InceptionV3/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_25.0/InceptionV3/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_20.0/InceptionV3/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_15.0/InceptionV3/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_10.0/InceptionV3/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_5.0/InceptionV3/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_100/ResNet50/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_95.0/ResNet50/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_90.0/ResNet50/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_85.0/ResNet50/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_80.0/ResNet50/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_75.0/ResNet50/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_70.0/ResNet50/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_65.0/ResNet50/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_60.0/ResNet50/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_55.0/ResNet50/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_50.0/ResNet50/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_45.0/ResNet50/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_40.0/ResNet50/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_35.0/ResNet50/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_30.0/ResNet50/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_25.0/ResNet50/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_20.0/ResNet50/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_15.0/ResNet50/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_10.0/ResNet50/metrics/csvs/_refined
# /media/william/NVME/projects/malaria-pibiti/6_resultados/Dataset01_5.0/ResNet50/metrics/csvs/_refined
